# %%
import requests
import json
import pandas as pd
import os
import matplotlib.pyplot as plt
from matplotlib import dates as mpl_dates

# %%
data = "resources/NYPD_Arrest_Data__Year_to_Date_.csv"
nypd_data = pd.read_csv(data)
nypd_data.head(2)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   214353678  06/18/2020  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1   210517846  03/04/2020  969.0  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
#
#                   OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0            FELONY ASSAULT  PL 1200501          F           K
# 1  OTHER TRAFFIC INFRACTION  VTL051101A          M           M
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               68                  0     18-24        F  WHITE HISPANIC
# 1               10                  0     25-44        M  BLACK HISPANIC
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0      978016      172087  40.639022 -74.022464
# 1      984331      209268  40.741077 -73.999709
#
#                        New Georeferenced Column
# 0  POINT (-74.02246352399999 40.63902167200007)
# 1  POINT (-73.99970914499994 40.74107715900004)

# %%
nypd_data[['Month','Day',"Year",]] = nypd_data["ARREST_DATE"].str.split("/",expand=True) 
nypd_data.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   214353678  06/18/2020  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1   210517846  03/04/2020  969.0  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 2   209190141  02/07/2020  569.0           MARIJUANA, SALE 4 & 5  235.0
# 3   208085722  01/17/2020  639.0         AGGRAVATED HARASSMENT 2  361.0
# 4   214476276  06/23/2020  105.0               STRANGULATION 1ST  106.0
#
#                        OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                 FELONY ASSAULT  PL 1200501          F           K
# 1       OTHER TRAFFIC INFRACTION  VTL051101A          M           M
# 2                DANGEROUS DRUGS  PL 2214000          M           K
# 3  OFF. AGNST PUB ORD SENSBLTY &  PL 2403002          M           Q
# 4                 FELONY ASSAULT  PL 1211200          F           B
#
#    ARREST_PRECINCT  ...  PERP_SEX       PERP_RACE X_COORD_CD Y_COORD_CD  \
# ...

# %%
clean_nypd_data = nypd_data[['Month','Day','Year','OFNS_DESC']]
clean_nypd_data.head(2)
# Out:
#   Month Day  Year                 OFNS_DESC
# 0    06  18  2020            FELONY ASSAULT
# 1    03  04  2020  OTHER TRAFFIC INFRACTION

# %%
Month = clean_nypd_data["Month"]
day = clean_nypd_data["day"]
deaths=clean_nypd_data["OFNS_DESC"]
    

#plt.plot(Mounth, positive,"g--", label="Positive")
plt.plot(Month, deaths,"r--", label="Deaths")
#plt.plot(Mounth, tested,"y--", label="Tested")


plt.title("Coronavirus cases in New York over time")
plt.xlabel("Month")
plt.ylabel("Number of cases")
plt.yticks()
plt.legend()


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-de2b5d3db3f4> in <module>
#       1 Month = clean_nypd_data["Month"]
# ...
