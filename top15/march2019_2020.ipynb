# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = "resources/2019data.csv"
data2020 = "resources/NYPD_Arrest_Data__Year_to_Date_.csv"
nypd_data = pd.read_csv(data, parse_dates=["ARREST_DATE"])
nypd_data2020 = pd.read_csv(data2020, parse_dates=["ARREST_DATE"])

# %%
march_data_19 = nypd_data.loc[(nypd_data["ARREST_DATE"] > "03/01/2019") & (nypd_data["ARREST_DATE"] < "04/01/2019"), :]
march_data_19.head()
# Out:
#       ARREST_DATE  PD_CD                         PD_DESC  \
# 37915  2019-03-02  201.0       TRESPASS 4,CRIMINAL SUB 2
# 37916  2019-03-02  478.0  THEFT OF SERVICES, UNCLASSIFIE
# 37917  2019-03-02  101.0                       ASSAULT 3
# 37918  2019-03-02  729.0  FORGERY,ETC.,UNCLASSIFIED-FELO
# 37919  2019-03-02  566.0           MARIJUANA, POSSESSION
#
#                             OFNS_DESC AGE_GROUP
# 37915         MISCELLANEOUS PENAL LAW     45-64
# 37916  OTHER OFFENSES RELATED TO THEF     25-44
# 37917    ASSAULT 3 & RELATED OFFENSES     18-24
# 37918                         FORGERY     25-44
# 37919         MISCELLANEOUS PENAL LAW     25-44

# %%
group_ofns_19 = march_data_19.groupby("OFNS_DESC")
count_ofns_19 = group_ofns_19["OFNS_DESC"].count().sort_values(ascending=False).head(15)
count_ofns_19
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      2546
# DANGEROUS DRUGS                   2047
# PETIT LARCENY                     1697
# VEHICLE AND TRAFFIC LAWS          1578
# FELONY ASSAULT                    1223
# MISCELLANEOUS PENAL LAW           1053
# GRAND LARCENY                      912
# CRIMINAL MISCHIEF & RELATED OF     905
# DANGEROUS WEAPONS                  791
# ROBBERY                            672
# OFFENSES AGAINST PUBLIC ADMINI     634
# OTHER OFFENSES RELATED TO THEF     476
# FORGERY                            465
# INTOXICATED & IMPAIRED DRIVING     461
# OFF. AGNST PUB ORD SENSBLTY &      408
# Name: OFNS_DESC, dtype: int64

# %%
plt.figure(figsize=(5,10))

ofns_chart_19 = count_ofns_19.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes March 2019", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.show()

# %%
march_data_20 = nypd_data2020.loc[(nypd_data2020["ARREST_DATE"] > "03/01/2020") & (nypd_data2020["ARREST_DATE"] < "04/01/2020"), :]
march_data_20.head()
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 1    210517846  2020-03-04  969.0  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 7    210784443  2020-03-10  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 12   210749767  2020-03-09  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 14   211047161  2020-03-15  114.0             OBSTR BREATH/CIRCUL  344.0
# 23   211343391  2020-03-22  101.0                       ASSAULT 3  344.0
#
#                        OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 1       OTHER TRAFFIC INFRACTION  VTL051101A          M           M
# 7                  PETIT LARCENY  PL 1552500          M           M
# 12      VEHICLE AND TRAFFIC LAWS  VTL1220B01          M           Q
# 14  ASSAULT 3 & RELATED OFFENSES  PL 1211100          M           K
# 23  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
#
#     ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
group_ofns_20 = march_data_20.groupby("OFNS_DESC")
count_ofns_20 = group_ofns_20["OFNS_DESC"].count().sort_values(ascending=False).head(15)
count_ofns_20
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      2065
# PETIT LARCENY                     1189
# FELONY ASSAULT                    1160
# DANGEROUS DRUGS                   1115
# MISCELLANEOUS PENAL LAW            783
# GRAND LARCENY                      718
# ROBBERY                            717
# CRIMINAL MISCHIEF & RELATED OF     653
# VEHICLE AND TRAFFIC LAWS           603
# DANGEROUS WEAPONS                  499
# OFFENSES AGAINST PUBLIC ADMINI     478
# BURGLARY                           464
# INTOXICATED & IMPAIRED DRIVING     221
# SEX CRIMES                         214
# OFF. AGNST PUB ORD SENSBLTY &      213
# Name: OFNS_DESC, dtype: int64

# %%
plt.figure(figsize=(5,10))

ofns_chart_20 = count_ofns_20.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes March 2020", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

ofns_chart_20 = count_ofns_20.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes March 2020", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

plt.subplot(1, 2, 2)
ofns_chart_19 = count_ofns_19.sort_values().plot(kind="barh", alpha=0.5, fontsize=10)
plt.title("Top 15 Crimes March 2019", fontsize=10)
plt.ylabel("Offense Type", fontsize=10)
plt.xlabel("Count", fontsize=10)

fig.tight_layout()
plt.show()

# %%
# use .loc
group_18_24 = march_data_19.loc[march_data_19["AGE_GROUP"] == "18-24"]

# use groupby
March_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
March_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      526
# DANGEROUS DRUGS                   334
# PETIT LARCENY                     275
# VEHICLE AND TRAFFIC LAWS          271
# FELONY ASSAULT                    259
# DANGEROUS WEAPONS                 247
# CRIMINAL MISCHIEF & RELATED OF    203
# MISCELLANEOUS PENAL LAW           189
# GRAND LARCENY                     178
# ROBBERY                           161
# OFFENSES AGAINST PUBLIC ADMINI    146
# OTHER OFFENSES RELATED TO THEF    142
# FORGERY                           123
# CRIMINAL TRESPASS                 115
# OFF. AGNST PUB ORD SENSBLTY &      84
# Name: ARREST_DATE, dtype: int64

# %%
# use .loc
group_25_44 = march_data_19.loc[march_data_19["AGE_GROUP"] == "25-44"]

# use groupby
March_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
March_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1403
# DANGEROUS DRUGS                   1100
# VEHICLE AND TRAFFIC LAWS           925
# PETIT LARCENY                      818
# FELONY ASSAULT                     686
# MISCELLANEOUS PENAL LAW            638
# CRIMINAL MISCHIEF & RELATED OF     510
# GRAND LARCENY                      480
# DANGEROUS WEAPONS                  373
# OFFENSES AGAINST PUBLIC ADMINI     351
# INTOXICATED & IMPAIRED DRIVING     313
# ROBBERY                            274
# FORGERY                            260
# OTHER OFFENSES RELATED TO THEF     230
# OFF. AGNST PUB ORD SENSBLTY &      222
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

March_group_18.sort_values().plot(kind="bar", color="r", alpha=0.7, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (March 2019)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
March_group_25.sort_values().plot(kind="bar", color="r", alpha=0.7, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (March 2019)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')

# %%
# use .loc
group_18_24 = march_data_20.loc[march_data_20["AGE_GROUP"] == "18-24"]

# use groupby
March_group_18 = group_18_24.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
March_group_18
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      407
# FELONY ASSAULT                    235
# ROBBERY                           199
# DANGEROUS DRUGS                   193
# DANGEROUS WEAPONS                 164
# CRIMINAL MISCHIEF & RELATED OF    158
# PETIT LARCENY                     145
# GRAND LARCENY                     137
# OFFENSES AGAINST PUBLIC ADMINI    133
# MISCELLANEOUS PENAL LAW           121
# VEHICLE AND TRAFFIC LAWS          110
# BURGLARY                           48
# FORGERY                            44
# OFF. AGNST PUB ORD SENSBLTY &      42
# GRAND LARCENY OF MOTOR VEHICLE     40
# Name: ARREST_DATE, dtype: int64

# %%
# use .loc
group_25_44 = march_data_20.loc[march_data_20["AGE_GROUP"] == "25-44"]

# use groupby
March_group_25 = group_25_44.groupby(["OFNS_DESC"]).count()["ARREST_DATE"].sort_values(ascending=False).head(15)
March_group_25
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      1154
# PETIT LARCENY                      661
# FELONY ASSAULT                     655
# DANGEROUS DRUGS                    590
# MISCELLANEOUS PENAL LAW            482
# CRIMINAL MISCHIEF & RELATED OF     380
# GRAND LARCENY                      361
# VEHICLE AND TRAFFIC LAWS           361
# OFFENSES AGAINST PUBLIC ADMINI     282
# ROBBERY                            260
# DANGEROUS WEAPONS                  245
# BURGLARY                           234
# INTOXICATED & IMPAIRED DRIVING     152
# SEX CRIMES                         131
# OFF. AGNST PUB ORD SENSBLTY &      127
# Name: ARREST_DATE, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plt.subplot(1, 2, 1)

March_group_18.sort_values().plot(kind="bar", color="green", alpha=0.6, fontsize=12)

plt.title("Age Group 18-24 vs. Crime (March 2020)", fontsize=12)
plt.ylabel("Number of Offenses", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)

plt.subplot(1, 2, 2)
March_group_25.sort_values().plot(kind="bar", color="green", alpha=0.6, fontsize=12)
plt.title("Age Group 25-44 vs. Crime (March 2020)", fontsize=12)
plt.xlabel("Offense Type", fontsize=12)
# Out:
# Text(0.5, 0, 'Offense Type')
